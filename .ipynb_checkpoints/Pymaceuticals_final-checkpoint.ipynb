# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - The overall analysis is that compared with the other drugs, Capomulin was most effective at reducing tumor volume.
# - The two drugs which showed the most reduction in tumor growth were Capomulin and Ramicane, over 45 days, the tumor size reduced as shown through the box plot diagram as well as the Summary data frame.
# - Capomulin and Ramicane have the lowest average tumor volume (mm3) as seen from the Summary data frame as well as through the box plot diagram. It's interesting to note that these drugs also had the highest number of timepoints for the datasets.
# - From observig the effectiveness of the drug from a daily standpoint, the line chart shows the pattern in which Capomulin reduces the tumor volume, spiking twice before reducing the size significantly.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
study_results_path = 'Study_results.csv'
mouse_metadata_path = 'Mouse_metadata.csv'


# Read the mouse data and the study results
study_results = pd.read_csv(study_results_path)
mouse_metadata = pd.read_csv(mouse_metadata_path)


# Combine the data into a single DataFrame
combined_df = pd.merge(mouse_metadata, study_results, how='right', on="Mouse ID")

# Display the data table for preview
combined_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        b128    Capomulin  Female           9          22          0
# 1        f932     Ketapril    Male          15          29          0
# 2        g107     Ketapril  Female           2          29          0
# 3        a457     Ketapril  Female          11          30          0
# 4        c819     Ketapril    Male          21          25          0
# ...       ...          ...     ...         ...         ...        ...
# 1888     r944    Capomulin    Male          12          25         45
# 1889     u364    Capomulin    Male          18          17         45
# 1890     p438     Ceftamin  Female          11          26         45
# 1891     x773      Placebo  Female          21          30         45
# 1892     b879     Stelasyn  Female           4          26         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
# Checking the number of mice.
number_mice = combined_df["Mouse ID"].count()
number_mice
# Out:
# 1893

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupe_miceid = combined_df[combined_df.duplicated(["Mouse ID", "Timepoint"])]
dupe_miceid
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 137      g989     Propriva  Female          21          26          0
# 360      g989     Propriva  Female          21          26          5
# 681      g989     Propriva  Female          21          26         10
# 869      g989     Propriva  Female          21          26         15
# 1111     g989     Propriva  Female          21          26         20
#
#       Tumor Volume (mm3)  Metastatic Sites
# 137            45.000000                 0
# 360            47.570392                 0
# 681            49.880528                 0
# 869            53.442020                 0
# 1111           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. Mouse ID g989 

combined_df.loc[combined_df["Mouse ID"]=="g989",:]
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 107      g989     Propriva  Female          21          26          0
# 137      g989     Propriva  Female          21          26          0
# 329      g989     Propriva  Female          21          26          5
# 360      g989     Propriva  Female          21          26          5
# 620      g989     Propriva  Female          21          26         10
# 681      g989     Propriva  Female          21          26         10
# 815      g989     Propriva  Female          21          26         15
# 869      g989     Propriva  Female          21          26         15
# 950      g989     Propriva  Female          21          26         20
# 1111     g989     Propriva  Female          21          26         20
# 1195     g989     Propriva  Female          21          26         25
# 1380     g989     Propriva  Female          21          26         30
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
Clean_df = combined_df[combined_df["Mouse ID"] != 'g989']
Clean_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        b128    Capomulin  Female           9          22          0
# 1        f932     Ketapril    Male          15          29          0
# 2        g107     Ketapril  Female           2          29          0
# 3        a457     Ketapril  Female          11          30          0
# 4        c819     Ketapril    Male          21          25          0
# ...       ...          ...     ...         ...         ...        ...
# 1888     r944    Capomulin    Male          12          25         45
# 1889     u364    Capomulin    Male          18          17         45
# 1890     p438     Ceftamin  Female          11          26         45
# 1891     x773      Placebo  Female          21          30         45
# 1892     b879     Stelasyn  Female           4          26         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
new_number_mice = Clean_df["Mouse ID"].unique()
number_mice = len(new_number_mice)
number_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mean = Clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean().map('{:.2f}'.format)
median = Clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].median().map('{:.2f}'.format)
var = Clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].var().map('{:.2f}'.format)
stddev = Clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].std().map('{:.2f}'.format)
sem = Clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem().map('{:.2f}'.format)
 
# Assemble the resulting series into a single summary DataFrame.
statistics_df = pd.DataFrame({"Mean Tumor Volume": mean, 
                              "Median Tumor Volume": median, 
                              "Tumor Volume Variance": var,
                              "Tumour Volume Std Dev.": stddev,
                              "Tumor Volume Std Err.": sem})
statistics_df
# Out:
#              Mean Tumor Volume Median Tumor Volume Tumor Volume Variance  \
# Drug Regimen
# Capomulin                40.68               41.56                 24.95
# Ceftamin                 52.59               51.78                 39.29
# Infubinol                52.88               51.82                 43.13
# Ketapril                 55.24               53.70                 68.55
# Naftisol                 54.33               52.51                 66.17
# Placebo                  54.03               52.29                 61.17
# Propriva                 52.32               50.45                 43.85
# Ramicane                 40.22               40.67                 23.49
# Stelasyn                 54.23               52.43                 59.45
# Zoniferol                53.24               51.82                 48.53
#
#              Tumour Volume Std Dev. Tumor Volume Std Err.
# Drug Regimen
# Capomulin                      4.99                  0.33
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
#statistics_df = statistics_df.agg({"Drug Regimen": [mean, median, var, stddev, sem], "Tumor Volume (mm3)": [mean, median, var, stddev, sem]})
#statistics_df

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
drug_reg = Clean_df.groupby("Drug Regimen")
drug_count = pd.DataFrame(drug_reg["Drug Regimen"].count())
drug_reg_bar = drug_count.plot(kind='bar', color="steelblue", figsize=(7,4))

# Create titles and axis labels
plt.title("Observed timepoints by each Drug Regimen type")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.tight_layout()
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
x_axis = np.arange(len(drug_count))
tick_loc = [value for value in x_axis]
plt.figure(figsize = (7,4))
plt.bar(x_axis, drug_count["Drug Regimen"], color='steelblue', alpha=1, align="center", width=0.75)
plt.xticks(tick_loc, list(drug_count.index), rotation="vertical")

#Plot the limits of the chart
plt.xlim(-0.5, len(x_axis)-0.5)
plt.ylim(0, max(drug_count["Drug Regimen"])+10)

#Create x and y axis labels
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
drug_reg = ["Drug Regimen"]
plt.legend(drug_reg, loc="best")
plt.tight_layout
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

counts = Clean_df.Sex.value_counts()
counts.plot(kind='pie', figsize=(7,4), y='Sex', autopct='%1.1f%%', colors=["violet", "steelblue"], legend=False)
plt.ylabel("Sex")
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

counts = Clean_df.Sex.value_counts()
colors = ["violet", "steelblue"]
plt.figure(figsize=(7,4))
plt.pie(counts.values, labels=counts.index.values, colors=colors, autopct="%1.1f%%", shadow=True)

#Add x and y axis labels
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin


# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = Clean_df.groupby(['Mouse ID'])
max_timepoint_byMouse_ID = last_timepoint['Timepoint'].max()
pd.DataFrame(max_timepoint_byMouse_ID)
max_timepoint_byMouse_ID
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merged_original = pd.merge(Clean_df, max_timepoint_byMouse_ID, how='right', on=["Mouse ID", "Timepoint"])
merged_original
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       a203    Infubinol  Female          20          23         45
# 1       a251    Infubinol  Female          21          25         45
# 2       a262      Placebo  Female          17          29         45
# 3       a275     Ceftamin  Female          20          28         45
# 4       a366     Stelasyn  Female          16          29         30
# ..       ...          ...     ...         ...         ...        ...
# 243     z435     Propriva  Female          12          26         10
# 244     z578     Ramicane    Male          11          16         45
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
drug_regimens = ['Capomulin','Ramicane','Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

for drug in drug_regimens:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    per_drug_tumor = merged_original.loc[merged_original['Drug Regimen']==drug,'Tumor Volume (mm3)']
    
    # add subset 
    tumor_vol.append(per_drug_tumor)
    
    # Determine outliers using upper and lower bounds
    quartiles = per_drug_tumor.quantile([.25, .5, .75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f'The potential outlier for {drug_regimens} is: {iqr}')
# Out:
# The potential outlier for ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] is: 7.781863460000004
# The potential outlier for ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] is: 9.098536719999998
# The potential outlier for ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] is: 11.477135160000003
# The potential outlier for ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'] is: 15.577752179999997

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()

ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.set_xlabel('Drug Regimen')
ax1.boxplot(tumor_vol)
ax1.set_xticklabels(drug_regimens)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
Clean_df

Clean_df['Mouse ID'].unique()
capo_mice = Clean_df.loc[Clean_df['Drug Regimen']=='Capomulin']
list_capo_mice = capo_mice['Mouse ID'].unique()
list_capo_mice

l509_mouse = capo_mice.loc[capo_mice["Mouse ID"]=='l509']
l509_mouse

l509_tumor_vol = l509_mouse['Tumor Volume (mm3)']
l509_timepoint = l509_mouse['Timepoint']

l509_line_plot=plt.plot(l509_timepoint, l509_tumor_vol,color='steelblue')
plt.title("Capolmulin treatment of mouse l509")
plt.ylabel("Tumor Volume (mm3)")
plt.xlabel("Timepoint (days)")
# Out:
# Text(0.5, 0, 'Timepoint (days)')

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
# Create the lists for mouse weight and ave tumor volume 
capo_mice = Clean_df.loc[Clean_df['Drug Regimen']=='Capomulin']
capo_mice_weight = capo_mice.groupby(['Mouse ID']).mean()['Weight (g)']
capo_mice_tumor_vol = capo_mice.groupby(['Mouse ID']).mean()['Tumor Volume (mm3)']

plt.scatter(capo_mice_weight, capo_mice_tumor_vol, marker='o', facecolors='steelblue')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
# Out:
# C:\Users\fordy\AppData\Local\Temp\ipykernel_7448\1481455976.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   capo_mice_weight = capo_mice.groupby(['Mouse ID']).mean()['Weight (g)']
# C:\Users\fordy\AppData\Local\Temp\ipykernel_7448\1481455976.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   capo_mice_tumor_vol = capo_mice.groupby(['Mouse ID']).mean()['Tumor Volume (mm3)']

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient
# for mouse weight and average observed  tumor volume for the entire Capomulin regimen
corr_calc = st.pearsonr(capo_mice_weight, capo_mice_tumor_vol)
print(f"The correlation coefficient between mouse weight and the average tumor volume is {round(corr_calc[0],3)}")
# Out:
# The correlation coefficient between mouse weight and the average tumor volume is 0.842

# %%
# Create a linear regression model for mouse weight and average observed  tumor volume for the entire Capomulin regimen
vc_slope, vc_int, vc_r, vc_p, vc_std_err = st.linregress(capo_mice_weight, capo_mice_tumor_vol)
vc_fit = vc_slope * capo_mice_weight + vc_int

plt.scatter(capo_mice_weight, capo_mice_tumor_vol, marker='o', facecolors='orange')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.plot(capo_mice_weight, vc_fit, "-")
plt.show()
